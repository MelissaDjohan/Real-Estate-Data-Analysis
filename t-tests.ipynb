# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load
austin_load = "CSV/avg_austin"


# Read the Data
austin_data_df = pd.read_csv(austin_load)
austin_data_df.head()
# Out:
#    Unnamed: 0  Year Built  Sale Amount
# 0           0        1950     100000.0
# 1           1        1955     194443.0
# 2           2        1956     309375.0
# 3           3        1958     450000.0
# 4           4        1962     254374.0

# %%
# remove the previous index
austin_data = austin_data_df[['Year Built', 'Sale Amount']]
austin_data.head()
# Out:
#    Year Built  Sale Amount
# 0        1950     100000.0
# 1        1955     194443.0
# 2        1956     309375.0
# 3        1958     450000.0
# 4        1962     254374.0

# %%
# File to Load
chicago_load = "CSV/avg_chicago"


# Read the Data
chicago_data_df = pd.read_csv(chicago_load)
chicago_data_df.head()
# Out:
#    Unnamed: 0  Year Built    Sale Amount
# 0           0        1941   87500.000000
# 1           1        1942   37333.333333
# 2           2        1943   62071.428571
# 3           3        1944  245000.000000
# 4           4        1945   61750.000000

# %%
# remove the previous index
chicago_data = chicago_data_df[['Year Built', 'Sale Amount']]
chicago_data.head()
# Out:
#    Year Built    Sale Amount
# 0        1941   87500.000000
# 1        1942   37333.333333
# 2        1943   62071.428571
# 3        1944  245000.000000
# 4        1945   61750.000000

# %%
# merge
merge_one = pd.merge(austin_data, chicago_data, on="Year Built", how="outer")

# rename merge columns
merge_one  = merge_one.rename(columns = {"Sale Amount_x": "Austin Avg", "Sale Amount_y" : "Chicago Avg"})

merge_one.head()
# Out:
#    Year Built  Austin Avg    Chicago Avg
# 0        1950    100000.0   59642.857143
# 1        1955    194443.0  135208.333333
# 2        1956    309375.0   59700.000000
# 3        1958    450000.0   85625.000000
# 4        1962    254374.0   43166.666667

# %%
# File to Load
cupertino_load = "CSV/avg_cupertino"

# Read the Data
cupertino_data_df = pd.read_csv(cupertino_load)
cupertino_data_df.head()
# Out:
#    Unnamed: 0  Year Built  Sale Amount
# 0           0        1942    2148000.0
# 1           1        1945    1870000.0
# 2           2        1948     793750.0
# 3           3        1950     610000.0
# 4           4        1951    1542500.0

# %%
# remove the previous index
cupertino_data = cupertino_data_df[['Year Built', 'Sale Amount']]
cupertino_data.head()
# Out:
#    Year Built  Sale Amount
# 0        1942    2148000.0
# 1        1945    1870000.0
# 2        1948     793750.0
# 3        1950     610000.0
# 4        1951    1542500.0

# %%
# merge
merge_two = pd.merge(merge_one, cupertino_data, on="Year Built", how="outer")

# rename merge columns
merge_two  = merge_two.rename(columns = {"Sale Amount": "Cupertino Avg"})

merge_two.head()
# Out:
#    Year Built  Austin Avg    Chicago Avg  Cupertino Avg
# 0        1950    100000.0   59642.857143   6.100000e+05
# 1        1955    194443.0  135208.333333   6.880000e+05
# 2        1956    309375.0   59700.000000            NaN
# 3        1958    450000.0   85625.000000   1.330056e+06
# 4        1962    254374.0   43166.666667   1.540009e+06

# %%
# File to Load
syracuse_load = "CSV/avg_syracuse"

# Read the Data
syracuse_data_df = pd.read_csv(syracuse_load)
syracuse_data_df.head()
# Out:
#    Unnamed: 0  Year Built  Sale Amount
# 0           0        1945     237500.0
# 1           1        1946     240130.0
# 2           2        1948     240586.5
# 3           3        1949     192231.0
# 4           4        1951     125905.0

# %%
# remove the previous index
syracuse_data = syracuse_data_df[['Year Built', 'Sale Amount']]
syracuse_data.head()
# Out:
#    Year Built  Sale Amount
# 0        1945     237500.0
# 1        1946     240130.0
# 2        1948     240586.5
# 3        1949     192231.0
# 4        1951     125905.0

# %%
# merge
merge_three = pd.merge(merge_two, syracuse_data, on="Year Built", how="outer")

# rename merge columns
merge_three  = merge_three.rename(columns = {"Sale Amount": "Syracuse Avg"})

merge_three
# Out:
#     Year Built     Austin Avg    Chicago Avg  Cupertino Avg   Syracuse Avg
# 0         1950  100000.000000   59642.857143   6.100000e+05            NaN
# 1         1955  194443.000000  135208.333333   6.880000e+05            NaN
# 2         1956  309375.000000   59700.000000            NaN            NaN
# 3         1958  450000.000000   85625.000000   1.330056e+06            NaN
# 4         1962  254374.000000   43166.666667   1.540009e+06  166869.000000
# 5         1965  151000.000000   83772.727273   1.499462e+06  137500.000000
# 6         1966  360000.000000   81785.714286   1.680918e+06  229344.333333
# 7         1967  287406.000000   62750.000000   1.527050e+06  210035.333333
# 8         1970  120000.000000   71000.000000   1.791100e+06  138888.000000
# 9         1971  354375.000000   76500.000000   1.800278e+06  257748.750000
# 10        1972  134611.000000   50166.666667   1.694479e+06  189057.333333
# 11        1973  305250.000000  113750.000000   1.668333e+06  245363.000000
# 12        1974  218265.125000   77833.333333            NaN            NaN
# 13        1975  301993.333333   39650.000000   1.515000e+06  153621.750000
# 14        1976  292884.100000  119166.666667   1.416857e+06  204066.777778
# 15        1977  231003.800000   65000.000000   1.555727e+06  151418.000000
# 16        1978  320866.166667  133000.000000   1.375727e+06  280062.500000
# 17        1979  230717.500000   59000.000000   2.124500e+06  188237.000000
# 18        1980  262788.300000  128500.000000   1.840700e+06  239898.571429
# 19        1981  248986.625000  280000.000000   1.147562e+06  167558.714286
# 20        1982  245501.714286            NaN   1.606607e+06  185372.500000
# 21        1983  228131.533333            NaN   2.026333e+06  174150.666667
# 22        1984  316931.000000            NaN   2.017714e+06            NaN
# 23        1985  198504.333333  219000.000000   2.240375e+06  244905.500000
# 24        1986  211435.250000  119000.000000   1.831130e+06  248334.750000
# 25        1987  212344.000000            NaN   1.817750e+06  165639.000000
# 26        1988  257758.200000            NaN   1.537045e+06  223340.000000
# 27        1989  256867.700000            NaN   1.555015e+06            NaN
# 28        1990  140429.000000            NaN   1.225260e+06  179995.000000
# 29        1991  421186.666667            NaN   1.848333e+06  283916.666667
# ..         ...            ...            ...            ...            ...
# 48        2010  210180.559140            NaN   1.420167e+06  300570.866667
# 49        2011  202333.476923            NaN            NaN  303978.333333
# 50        2012  203712.235294            NaN   1.280250e+06  319707.200000
# 51        2013  222256.260870            NaN   2.038000e+06  368587.636364
# 52        2014  222399.226804            NaN   5.945000e+05  323298.520000
# 53        2015  229295.371429            NaN   1.755000e+06  330461.636364
# 54        2016  258593.845070            NaN   1.431000e+06  325368.420455
# 55        2017  285454.283582            NaN   1.677833e+06  337482.855072
# 56        2018  454332.000000            NaN   1.039000e+06  300519.000000
# 57        1941            NaN   87500.000000            NaN            NaN
# 58        1942            NaN   37333.333333   2.148000e+06            NaN
# 59        1943            NaN   62071.428571            NaN            NaN
# 60        1944            NaN  245000.000000            NaN            NaN
# 61        1945            NaN   61750.000000   1.870000e+06  237500.000000
# 62        1946            NaN   84100.000000            NaN  240130.000000
# 63        1947            NaN   35000.000000            NaN            NaN
# 64        1948            NaN   36083.333333   7.937500e+05  240586.500000
# 65        1949            NaN   89863.636364            NaN  192231.000000
# 66        1951            NaN   70947.368421   1.542500e+06  125905.000000
# 67        1952            NaN  116406.250000            NaN  255750.000000
# 68        1953            NaN   88657.894737   1.570033e+06            NaN
# 69        1954            NaN  108066.666667   1.475000e+06            NaN
# 70        1957            NaN   92896.000000   1.932500e+06            NaN
# 71        1959            NaN   96045.454545   1.501167e+06            NaN
# 72        1960            NaN    8333.333333   1.368538e+06            NaN
# 73        1961            NaN  117700.000000   1.143155e+06  209826.000000
# 74        1963            NaN   28500.000000   1.383667e+06  217934.000000
# 75        1964            NaN  174230.769231   1.444210e+06            NaN
# 76        1968            NaN   88571.428571   1.442828e+06  237719.000000
# 77        1969            NaN  136000.000000   1.785714e+06  173768.000000
#
# [78 rows x 5 columns]

# %%
# looking at the data, the best set to use for all cities would be 1970-1973
# call upon data using loc
four_cities = merge_three.iloc[[8,9,10,11],:]
four_cities
# Out:
#     Year Built  Austin Avg    Chicago Avg  Cupertino Avg   Syracuse Avg
# 8         1970    120000.0   71000.000000   1.791100e+06  138888.000000
# 9         1971    354375.0   76500.000000   1.800278e+06  257748.750000
# 10        1972    134611.0   50166.666667   1.694479e+06  189057.333333
# 11        1973    305250.0  113750.000000   1.668333e+06  245363.000000

# %%
# create dataframe
summary_table = pd.DataFrame(four_cities)

summary_table.set_index('Year Built', inplace=True)
summary_table
# Out:
#             Austin Avg    Chicago Avg  Cupertino Avg   Syracuse Avg
# Year Built
# 1970          120000.0   71000.000000   1.791100e+06  138888.000000
# 1971          354375.0   76500.000000   1.800278e+06  257748.750000
# 1972          134611.0   50166.666667   1.694479e+06  189057.333333
# 1973          305250.0  113750.000000   1.668333e+06  245363.000000

# %%
austin = summary_table.iloc[:,[0]]
chicago = summary_table.iloc[:,[1]]
cupertino = summary_table.iloc[:,[2]]
syracuse = summary_table.iloc[:,[3]]

# %%
# Create a boxplot to compare means
summary_table.plot(kind='box')

# %%
# T-Tests
test_one = stats.ttest_ind(austin, chicago, equal_var=False)
test_two = stats.ttest_ind(austin, cupertino, equal_var=False)
test_three = stats.ttest_ind(austin, syracuse, equal_var=False)
test_four = stats.ttest_ind(chicago, cupertino, equal_var=False)
test_five = stats.ttest_ind(chicago, syracuse, equal_var=False)
test_six = stats.ttest_ind(syracuse, cupertino, equal_var=False)

print(test_one)
print(test_two)
print(test_three)
print(test_four)
print(test_five)
print(test_six)
# Out:
# Ttest_indResult(statistic=array([2.4768365]), pvalue=array([0.08187951]))
# Ttest_indResult(statistic=array([-22.15011769]), pvalue=array([5.81653574e-06]))
# Ttest_indResult(statistic=array([0.31795435]), pvalue=array([0.76563168]))
# Ttest_indResult(statistic=array([-46.13576947]), pvalue=array([1.66185813e-06]))
# Ttest_indResult(statistic=array([-4.26950963]), pvalue=array([0.01091587]))
# Ttest_indResult(statistic=array([-35.39092275]), pvalue=array([5.65246921e-08]))

# %%
# for most recent years, we would have too drop chicago
three_cities = merge_three.loc[[50,51,52,53,54,55,56],:]
three_cities
# Out:
#     Year Built     Austin Avg  Chicago Avg  Cupertino Avg   Syracuse Avg
# 50        2012  203712.235294          NaN   1.280250e+06  319707.200000
# 51        2013  222256.260870          NaN   2.038000e+06  368587.636364
# 52        2014  222399.226804          NaN   5.945000e+05  323298.520000
# 53        2015  229295.371429          NaN   1.755000e+06  330461.636364
# 54        2016  258593.845070          NaN   1.431000e+06  325368.420455
# 55        2017  285454.283582          NaN   1.677833e+06  337482.855072
# 56        2018  454332.000000          NaN   1.039000e+06  300519.000000
